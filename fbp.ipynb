# %% [markdown]
# <a href="https://colab.research.google.com/github/faizan-abbas-mir/TSD/blob/main/fbp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pystan
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# !pip install prophet
# Out:
# Requirement already satisfied: pystan in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: aiohttp<4.0,>=3.6 in /usr/local/lib/python3.11/dist-packages (from pystan) (3.12.15)
# Requirement already satisfied: clikit<0.7,>=0.6 in /usr/local/lib/python3.11/dist-packages (from pystan) (0.6.2)
# Requirement already satisfied: httpstan<4.14,>=4.13 in /usr/local/lib/python3.11/dist-packages (from pystan) (4.13.0)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.11/dist-packages (from pystan) (2.0.2)
# Requirement already satisfied: pysimdjson<7,>=5.0.2 in /usr/local/lib/python3.11/dist-packages (from pystan) (6.0.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from pystan) (75.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0,>=3.6->pystan) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0,>=3.6->pystan) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0,>=3.6->pystan) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0,>=3.6->pystan) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0,>=3.6->pystan) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0,>=3.6->pystan) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0,>=3.6->pystan) (1.20.1)
# Requirement already satisfied: crashtest<0.4.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from clikit<0.7,>=0.6->pystan) (0.3.1)
# Requirement already satisfied: pastel<0.3.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from clikit<0.7,>=0.6->pystan) (0.2.1)
# Requirement already satisfied: pylev<2.0,>=1.3 in /usr/local/lib/python3.11/dist-packages (from clikit<0.7,>=0.6->pystan) (1.4.0)
# Requirement already satisfied: appdirs<2.0,>=1.4 in /usr/local/lib/python3.11/dist-packages (from httpstan<4.14,>=4.13->pystan) (1.4.4)
# Requirement already satisfied: marshmallow<4.0,>=3.10 in /usr/local/lib/python3.11/dist-packages (from httpstan<4.14,>=4.13->pystan) (3.26.1)
# Requirement already satisfied: webargs<9.0,>=8.0 in /usr/local/lib/python3.11/dist-packages (from httpstan<4.14,>=4.13->pystan) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from aiosignal>=1.4.0->aiohttp<4.0,>=3.6->pystan) (4.14.1)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.11/dist-packages (from marshmallow<4.0,>=3.10->httpstan<4.14,>=4.13->pystan) (25.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.17.0->aiohttp<4.0,>=3.6->pystan) (3.10)
# Requirement already satisfied: prophet in /usr/local/lib/python3.11/dist-packages (1.1.7)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from prophet) (1.2.5)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.11/dist-packages (from prophet) (2.0.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from prophet) (3.10.0)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from prophet) (2.2.2)
# Requirement already satisfied: holidays<1,>=0.25 in /usr/local/lib/python3.11/dist-packages (from prophet) (0.78)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.11/dist-packages (from prophet) (4.67.1)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from prophet) (6.5.2)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.17.0)

# %%
df= pd.read_csv('AirPassengers.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    object
#  1   #Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
df.isnull().sum()
# Out:
# Month          0
# #Passengers    0
# dtype: int64

# %%
df.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
df.tail()
# Out:
#        Month  #Passengers
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432

# %%
df.plot(

)
# Out:
# <Axes: >

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    object
#  1   #Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
df.columns=['ds','y']
df.head()
# Out:
#         ds    y
# 0  1949-01  112
# 1  1949-02  118
# 2  1949-03  132
# 3  1949-04  129
# 4  1949-05  121

# %%
df['ds']=pd.to_datetime(df['ds'])

# %%
df.head()
# Out:
#           ds    y
# 0 1949-01-01  112
# 1 1949-02-01  118
# 2 1949-03-01  132
# 3 1949-04-01  129
# 4 1949-05-01  121

# %%
from prophet import Prophet

# %%
dir(Prophet)
# Out:
# ['__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_load_stan_backend',
#  '_logistic_uncertainty',
#  '_make_historical_mat_time',
#  '_make_trend_shift_matrix',
#  '_sample_uncertainty',
#  'add_country_holidays',
#  'add_group_component',
#  'add_regressor',
#  'add_seasonality',
#  'calculate_initial_params',
#  'construct_holiday_dataframe',
#  'fit',
#  'flat_growth_init',
#  'flat_trend',
#  'fourier_series',
#  'initialize_scales',
#  'linear_growth_init',
#  'logistic_growth_init',
#  'make_all_seasonality_features',
#  'make_future_dataframe',
#  'make_holiday_features',
#  'make_seasonality_features',
#  'parse_seasonality_args',
#  'percentile',
#  'piecewise_linear',
#  'piecewise_logistic',
#  'plot',
#  'plot_components',
#  'predict',
#  'predict_seasonal_components',
#  'predict_trend',
#  'predict_uncertainty',
#  'predictive_samples',
#  'preprocess',
#  'regressor_column_matrix',
#  'sample_model',
#  'sample_model_vectorized',
#  'sample_posterior_predictive',
#  'sample_predictive_trend',
#  'sample_predictive_trend_vectorized',
#  'set_auto_seasonalities',
#  'set_changepoints',
#  'setup_dataframe',
#  'validate_column_name',
#  'validate_inputs']

# %%
model= Prophet()

# %%
df.columns
# Out:
# Index(['ds', 'y'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      144 non-null    datetime64[ns]
#  1   y       144 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.4 KB

# %%
model.fit(df)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/yj7w96qb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/pg_tsu37.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87344', 'data', 'file=/tmp/tmporie1f26/yj7w96qb.json', 'init=/tmp/tmporie1f26/pg_tsu37.json', 'output', 'file=/tmp/tmporie1f26/prophet_modeltysk3d5j/prophet_model-20250810175154.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:51:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:51:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
model.component_modes
# Out:
# {'additive': ['yearly',
#   'additive_terms',
#   'extra_regressors_additive',
#   'holidays'],
#  'multiplicative': ['multiplicative_terms', 'extra_regressors_multiplicative']}

# %%
df.tail()
# Out:
#             ds    y
# 139 1960-08-01  606
# 140 1960-09-01  508
# 141 1960-10-01  461
# 142 1960-11-01  390
# 143 1960-12-01  432

# %%
future_dates=model.make_future_dataframe(periods=365)

# %%
future_dates
# Out:
#             ds
# 0   1949-01-01
# 1   1949-02-01
# 2   1949-03-01
# 3   1949-04-01
# 4   1949-05-01
# ..         ...
# 504 1961-11-27
# 505 1961-11-28
# 506 1961-11-29
# 507 1961-11-30
# 508 1961-12-01
#
# [509 rows x 1 columns]

# %%
prediction=model.predict(future_dates)

# %%
prediction.head()
# Out:
#           ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 1949-01-01  107.406338   57.002447  114.144681   107.406338   107.406338
# 1 1949-02-01  109.550561   50.506714  108.686299   109.550561   109.550561
# 2 1949-03-01  111.487279   80.472718  140.476041   111.487279   111.487279
# 3 1949-04-01  113.631502   80.302730  136.093256   113.631502   113.631502
# 4 1949-05-01  115.706556   84.226501  140.265073   115.706556   115.706556
#
#    additive_terms  additive_terms_lower  additive_terms_upper     yearly  \
# 0      -21.387455            -21.387455            -21.387455 -21.387455
# 1      -30.055335            -30.055335            -30.055335 -30.055335
# 2       -0.461698             -0.461698             -0.461698  -0.461698
# 3       -4.912485             -4.912485             -4.912485  -4.912485
# 4       -3.611275             -3.611275             -3.611275  -3.611275
#
#    yearly_lower  yearly_upper  multiplicative_terms  \
# 0    -21.387455    -21.387455                   0.0
# 1    -30.055335    -30.055335                   0.0
# 2     -0.461698     -0.461698                   0.0
# 3     -4.912485     -4.912485                   0.0
# 4     -3.611275     -3.611275                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper        yhat
# 0                         0.0                         0.0   86.018883
# 1                         0.0                         0.0   79.495226
# 2                         0.0                         0.0  111.025581
# 3                         0.0                         0.0  108.719017
# 4                         0.0                         0.0  112.095281

# %%
model.plot(prediction)

# %%
model.plot_components(prediction)

# %%
from prophet.diagnostics import cross_validation
df_cv= cross_validation(model, initial='730 days', period='180 days', horizon='365 days')
# Out:
# INFO:prophet:Making 19 forecasts with cutoffs between 1951-01-18 00:00:00 and 1959-12-02 00:00:00
#   0%|          | 0/19 [00:00<?, ?it/s]
# INFO:prophet:n_changepoints greater than number of observations. Using 19.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/l1chnp09.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/yk8u5qpo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43345', 'data', 'file=/tmp/tmporie1f26/l1chnp09.json', 'init=/tmp/tmporie1f26/yk8u5qpo.json', 'output', 'file=/tmp/tmporie1f26/prophet_modelb6ejchyv/prophet_model-20250810175834.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:58:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:58:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 23.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/0p8scmks.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/zns91odw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68517', 'data', 'file=/tmp/tmporie1f26/0p8scmks.json', 'init=/tmp/tmporie1f26/zns91odw.json', 'output', 'file=/tmp/tmporie1f26/prophet_modeltldp6qz1/prophet_model-20250810175849.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:58:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:58:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/lv62ru7s.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/w4zmijhl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=32456', 'data', 'file=/tmp/tmporie1f26/lv62ru7s.json', 'init=/tmp/tmporie1f26/w4zmijhl.json', 'output', 'file=/tmp/tmporie1f26/prophet_model9j86rie7/prophet_model-20250810175849.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:58:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:58:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/dp0h86jv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/hdr_whda.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47347', 'data', 'file=/tmp/tmporie1f26/dp0h86jv.json', 'init=/tmp/tmporie1f26/hdr_whda.json', 'output', 'file=/tmp/tmporie1f26/prophet_model78exg5r_/prophet_model-20250810175849.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:58:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:58:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/isl4zi_3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/xy0bm63l.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=55086', 'data', 'file=/tmp/tmporie1f26/isl4zi_3.json', 'init=/tmp/tmporie1f26/xy0bm63l.json', 'output', 'file=/tmp/tmporie1f26/prophet_modelqhivzy0c/prophet_model-20250810175850.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:58:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:58:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/0t2yomtz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/hzy6py3x.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85377', 'data', 'file=/tmp/tmporie1f26/0t2yomtz.json', 'init=/tmp/tmporie1f26/hzy6py3x.json', 'output', 'file=/tmp/tmporie1f26/prophet_model6toal1uy/prophet_model-20250810175850.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:58:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:58:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/t47r1csc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/7zz0xqjy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17261', 'data', 'file=/tmp/tmporie1f26/t47r1csc.json', 'init=/tmp/tmporie1f26/7zz0xqjy.json', 'output', 'file=/tmp/tmporie1f26/prophet_modelgxciv04b/prophet_model-20250810175851.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:58:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:58:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/r2jhs458.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/l2zjcta7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64919', 'data', 'file=/tmp/tmporie1f26/r2jhs458.json', 'init=/tmp/tmporie1f26/l2zjcta7.json', 'output', 'file=/tmp/tmporie1f26/prophet_modelzqss8o4e/prophet_model-20250810175851.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:58:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:58:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/rwz13cvj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/eim572tk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=69909', 'data', 'file=/tmp/tmporie1f26/rwz13cvj.json', 'init=/tmp/tmporie1f26/eim572tk.json', 'output', 'file=/tmp/tmporie1f26/prophet_modelahykthxa/prophet_model-20250810175851.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:58:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:58:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/0drukylg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/wr9jjqfi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72153', 'data', 'file=/tmp/tmporie1f26/0drukylg.json', 'init=/tmp/tmporie1f26/wr9jjqfi.json', 'output', 'file=/tmp/tmporie1f26/prophet_model0ad4wd9w/prophet_model-20250810175852.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:58:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:58:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/nfge_se5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/6ecpv7a0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=81433', 'data', 'file=/tmp/tmporie1f26/nfge_se5.json', 'init=/tmp/tmporie1f26/6ecpv7a0.json', 'output', 'file=/tmp/tmporie1f26/prophet_modeleedfcpv7/prophet_model-20250810175853.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:58:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:58:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/xxd_a2qp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/fbz8gizo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=21488', 'data', 'file=/tmp/tmporie1f26/xxd_a2qp.json', 'init=/tmp/tmporie1f26/fbz8gizo.json', 'output', 'file=/tmp/tmporie1f26/prophet_modelivvki9bx/prophet_model-20250810175854.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:58:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:58:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/a053ucco.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/mqlkpew6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87273', 'data', 'file=/tmp/tmporie1f26/a053ucco.json', 'init=/tmp/tmporie1f26/mqlkpew6.json', 'output', 'file=/tmp/tmporie1f26/prophet_model3csaetqo/prophet_model-20250810175855.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 17:58:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:58:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/z1vbezhh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/9lhozpg3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=138', 'data', 'file=/tmp/tmporie1f26/z1vbezhh.json', 'init=/tmp/tmporie1f26/9lhozpg3.json', 'output', 'file=/tmp/tmporie1f26/prophet_modeljsvanj3d/prophet_model-20250810175855.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:58:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:58:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/jfz1k03z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/m27f05or.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=10751', 'data', 'file=/tmp/tmporie1f26/jfz1k03z.json', 'init=/tmp/tmporie1f26/m27f05or.json', 'output', 'file=/tmp/tmporie1f26/prophet_model4y9ay3qb/prophet_model-20250810175855.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:58:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:58:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/y5sn5di5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/huov777w.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59789', 'data', 'file=/tmp/tmporie1f26/y5sn5di5.json', 'init=/tmp/tmporie1f26/huov777w.json', 'output', 'file=/tmp/tmporie1f26/prophet_model6kxvhtq9/prophet_model-20250810175855.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:58:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:58:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/x5jgwxpe.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/3_pyro1u.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90862', 'data', 'file=/tmp/tmporie1f26/x5jgwxpe.json', 'init=/tmp/tmporie1f26/3_pyro1u.json', 'output', 'file=/tmp/tmporie1f26/prophet_modelcr8dpsls/prophet_model-20250810175855.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:58:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:58:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/hc2_c_pk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/96db0xoo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27224', 'data', 'file=/tmp/tmporie1f26/hc2_c_pk.json', 'init=/tmp/tmporie1f26/96db0xoo.json', 'output', 'file=/tmp/tmporie1f26/prophet_modelqvob8r77/prophet_model-20250810175855.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:58:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:58:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/2pjb6n1z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmporie1f26/trv00is2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76093', 'data', 'file=/tmp/tmporie1f26/2pjb6n1z.json', 'init=/tmp/tmporie1f26/trv00is2.json', 'output', 'file=/tmp/tmporie1f26/prophet_model63tf4kuy/prophet_model-20250810175856.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:58:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:58:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
df_cv.head()
# Out:
#           ds        yhat  yhat_lower  yhat_upper    y     cutoff
# 0 1951-02-01  158.547043  158.295800  158.767718  150 1951-01-18
# 1 1951-03-01  171.930554  171.161728  172.690577  178 1951-01-18
# 2 1951-04-01  160.294061  158.786218  161.794549  163 1951-01-18
# 3 1951-05-01  146.088671  143.657092  148.507022  172 1951-01-18
# 4 1951-06-01  181.775393  178.383293  185.361574  178 1951-01-18

# %%
from prophet.diagnostics import performance_metrics
df_p= performance_metrics(df_cv)
df_p
# Out:
#      horizon          mse       rmse        mae      mape     mdape     smape  \
# 0    40 days  1089.760435  33.011520  25.888183  0.078584  0.073832  0.079624
# 1    42 days  1015.074527  31.860234  25.207161  0.076726  0.073832  0.077409
# 2    46 days   909.815509  30.163148  24.622042  0.078579  0.078888  0.078319
# 3    47 days  1044.416363  32.317431  26.737368  0.081351  0.085408  0.081498
# 4    48 days  1034.025454  32.156266  26.194461  0.079480  0.085408  0.079693
# ..       ...          ...        ...        ...       ...       ...       ...
# 165 359 days   766.600337  27.687548  21.654293  0.068947  0.062001  0.068551
# 166 360 days   770.123742  27.751103  21.933194  0.069808  0.062001  0.069431
# 167 362 days   864.691069  29.405630  23.203429  0.068900  0.062001  0.069029
# 168 364 days   838.273512  28.952953  22.134290  0.065984  0.050250  0.066210
# 169 365 days   980.885591  31.319093  24.017554  0.071239  0.059901  0.072069
#
#      coverage
# 0    0.227273
# 1    0.181818
# 2    0.136364
# 3    0.136364
# 4    0.181818
# ..        ...
# 165  0.295455
# 166  0.272727
# 167  0.272727
# 168  0.272727
# 169  0.318182
#
# [170 rows x 8 columns]

# %%
from prophet.plot import plot_cross_validation_metric
fig= plot_cross_validation_metric(df_cv,metric= 'rmse')
# Out:
# /usr/local/lib/python3.11/dist-packages/prophet/plot.py:547: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   x_plt = df_none['horizon'].astype('timedelta64[ns]').view(np.int64) / float(dt_conversions[i])
# /usr/local/lib/python3.11/dist-packages/prophet/plot.py:548: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   x_plt_h = df_h['horizon'].astype('timedelta64[ns]').view(np.int64) / float(dt_conversions[i])
